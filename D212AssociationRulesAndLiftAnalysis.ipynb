# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# # Read in Dataset

# %%
# Load the dataset
file_path = '/Users/deadrienhill/codeup-data-science/oneil-clustering-exercises/D212_Churn_Clean.csv'  
df = pd.read_csv(file_path)
# Display first few rows
df.head()
# Out:
#    CaseOrder Customer_id                           Interaction  \
# 0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2          3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3          4      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4          5     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
#
#                                 UID         City State                 County  \
# 0  e885b299883d4f9fb18e39c75155d990  Point Baker    AK  Prince of Wales-Hyder
# 1  f2de8bef964785f41a2959829830fb8a  West Branch    MI                 Ogemaw
# 2  f1784cfa9f6d92ae816197eb175d3c71      Yamhill    OR                Yamhill
# 3  dc8a365077241bb5cd5ccd305136b05e      Del Mar    CA              San Diego
# 4  aabb64a116e83fdc4befc1fbab1663f9    Needville    TX              Fort Bend
#
#      Zip       Lat        Lng  ...  MonthlyCharge Bandwidth_GB_Year Item1  \
# 0  99927  56.25100 -133.37571  ...     172.455519        904.536110     5
# 1  48661  44.32893  -84.24080  ...     242.632554        800.982766     3
# 2  97148  45.35589 -123.24657  ...     159.947583       2054.706961     4
# 3  92014  32.96687 -117.24798  ...     119.956840       2164.579412     4
# 4  77461  29.38012  -95.80673  ...     149.948316        271.493436     4
#
#   Item2  Item3  Item4  Item5 Item6 Item7 Item8
# 0     5      5      3      4     4     3     4
# 1     4      3      3      4     3     4     4
# 2     4      2      4      4     3     3     3
# 3     4      4      2      5     4     3     3
# 4     4      4      3      4     4     4     5
#
# [5 rows x 50 columns]

# %% [markdown]
# # Prep Service Related Columns

# %%
# Service related columns
service_columns = ['InternetService', 'Phone', 'StreamingTV', 'StreamingMovies', 
                   'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport']
service_df = df[service_columns]

# %%
# Convert service columns into transactional format
transactions = service_df.apply(lambda col: col.map(str)).values.tolist()

# %%
# One Hot encode with the TransactionEncoder
te = TransactionEncoder()
te_data = te.fit_transform(transactions)
df_transformed = pd.DataFrame(te_data, columns=te.columns_)

# %% [markdown]
# # Apply Apriori algorithm

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(df_transformed, min_support=0.05, use_colnames=True)

# %%
# Generate association rules
num_itemsets = len(frequent_itemsets)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0, num_itemsets=num_itemsets)

# %%
# Display the top frequent itemsets and association rules
print("Frequent Itemsets:")
print(frequent_itemsets.sort_values(by="support", ascending=False).head(10))

print("\nAssociation Rules:")
print(rules.sort_values(by="lift", ascending=False).head(10))
# Out:
# Frequent Itemsets:
#     support                itemsets
# 3    0.9976                   (Yes)
# 2    0.9949                    (No)
# 8    0.9925               (No, Yes)
# 1    0.6537           (Fiber Optic)
# 7    0.6521      (Fiber Optic, Yes)
# 6    0.6510       (No, Fiber Optic)
# 10   0.6494  (No, Fiber Optic, Yes)
# 0    0.3463                   (DSL)
# 5    0.3455              (DSL, Yes)
# 4    0.3439               (DSL, No)
#
# Association Rules:
#           antecedents         consequents  antecedent support  \
# 2                (No)       (Fiber Optic)              0.9949
# 3       (Fiber Optic)                (No)              0.6537
# 8                (No)  (Fiber Optic, Yes)              0.9949
# 7  (Fiber Optic, Yes)                (No)              0.6521
# 6           (No, Yes)       (Fiber Optic)              0.9925
# 9       (Fiber Optic)           (No, Yes)              0.6537
# 0               (DSL)               (Yes)              0.3463
# 1               (Yes)               (DSL)              0.9976
# 4           (DSL, No)               (Yes)              0.3439
# 5               (Yes)           (DSL, No)              0.9976
#
#    consequent support  support  confidence      lift  representativity  \
# 2              0.6537   0.6510    0.654337  1.000975               1.0
# 3              0.9949   0.6510    0.995870  1.000975               1.0
# 8              0.6521   0.6494    0.652729  1.000964               1.0
# 7              0.9949   0.6494    0.995860  1.000964               1.0
# 6              0.6537   0.6494    0.654307  1.000929               1.0
# 9              0.9925   0.6494    0.993422  1.000929               1.0
# 0              0.9976   0.3455    0.997690  1.000090               1.0
# 1              0.3463   0.3455    0.346331  1.000090               1.0
# 4              0.9976   0.3431    0.997674  1.000074               1.0
# 5              0.3439   0.3431    0.343925  1.000074               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 2  0.000634    1.001843       0.190919  0.652566   0.001840    0.825103
# 3  0.000634    1.234767       0.002812  0.652566   0.190130    0.825103
# 8  0.000626    1.001811       0.188926  0.650962   0.001808    0.824294
# 7  0.000626    1.231744       0.002770  0.650962   0.188143    0.824294
# 6  0.000603    1.001757       0.123755  0.651485   0.001754    0.823865
# 9  0.000603    1.140174       0.002680  0.651485   0.122941    0.823865
# 0  0.000031    1.038900       0.000138  0.346054   0.037443    0.672011
# 1  0.000031    1.000048       0.037530  0.346054   0.000048    0.672011
# 4  0.000025    1.031700       0.000113  0.343650   0.030726    0.670800
# 5  0.000025    1.000039       0.030798  0.343650   0.000039    0.670800

# %%
# Save to CSV
frequent_itemsets.to_csv("frequent_itemsets.csv", index=False)
rules.to_csv("association_rules.csv", index=False)
